# %%
import pandas as pd

# %%
new_data = '../data/pre/new_generated_train.csv'

data = pd.read_csv(new_data)

# %%
data.head
# Out:
# <bound method NDFrame.head of          Unnamed: 0  age  gender  education  marriageStatus  haveBaby  \
# 0                 0   25       2          1               3         1
# 1                 1   20       2          1               1         0
# 2                 2   16       1          1               0         0
# 3                 3    0       0          0               0         0
# 4                 4   35       1          2               2         0
# 5                 5   30       2          1               2         1
# 6                 6   24       2          2               1         0
# 7                 7   15       2          3               0         0
# 8                 8   19       1          1               1         0
# 9                 9   19       1          1               1         0
# 10               10   19       1          0               2         1
# 11               11    8       2          0               2         1
# ...
